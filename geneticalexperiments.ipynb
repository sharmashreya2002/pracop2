# %% [markdown]
# Run an ensemble (x25 runs) of Standard GA varying population size (50, 75, 90, 100, 150, 200) and mutation probability 0.1.

# %%
import numpy as np
from geneticalgorithm import geneticalgorithm as ga
import math

def f(X):
    """Keane's Bump function.
    n = dimension of the domain
    x = vector in the domain"""
    cos4 = 0
    cos2 = 1
    x_i = 0
    n = len(X)
    for i in range(n):
        cos4 += math.cos(X[i])**4
        cos2 *= math.cos(X[i])**2
        x_i += (i+1)*(X[i]**2)
    if x_i == 0:
        answer = None
    else:
        answer = np.abs((cos4 - 2*cos2)/math.sqrt(x_i))
    ## we are turning the maximization problem into a minimization problem
    objective = -1 * answer
    ## we are adding a penalty for the constraint if either is violated!
    if np.sum(X) > 15 * len(X) / 2 or np.prod(X) < 0.75:
        ## penalty has to be larger than objective function value
        penalty = 2
    else:
        penalty = 0
    return objective + penalty

## 8D case
n = 8

varbound=np.array([[0,10]]*n)

algorithm_param = {'max_num_iteration': 10000,\
                   'population_size':200,\
                   'mutation_probability':0.1,\
                   'elit_ratio': 0,\
                   'crossover_probability': 0.5,\
                   'parents_portion': 0.3,\
                   'crossover_type':'uniform',\
                   'max_iteration_without_improv':3000, \
                    'convergence_curve': 'False'}

def run_ensemble():
    best_sols = []
    for i in range(25):
        model=ga(function=f,dimension=n,variable_type='real',variable_boundaries=varbound, algorithm_parameters=algorithm_param)
        model.run()
        solution=model.output_dict
        print(solution)
        best_sols.append(solution)
    return best_sols

# %%
def run_ensemble(algorithm_param):
    best_sols = []
    for i in range(25):
        model=ga(function=f,dimension=n,variable_type='real',variable_boundaries=varbound, algorithm_parameters=algorithm_param)
        model.run()
        solution=model.output_dict
        best_sols.append(solution['function'])
    return np.average(best_sols)

algorithm_param = {'max_num_iteration': 10000,\
                   'population_size':400,\
                   'mutation_probability':0.1,\
                   'elit_ratio': 0,\
                   'crossover_probability': 0.5,\
                   'parents_portion': 0.3,\
                   'crossover_type':'uniform',\
                   'max_iteration_without_improv':1000, \
                    'convergence_curve': False}
best_sol = run_ensemble(algorithm_param)
# Out:
#  The best solution found:
#  [3.44337371 2.56535251 0.08425807 3.02750217 3.21348148 0.08928277
#  3.07151494 1.55700588]
#
#  Objective function:
#  -0.44321743830113675
#  The best solution found:
#  [3.11104071 0.57873616 3.27799874 0.4913135  1.67317879 0.75757542
#  3.00181845 0.38984362]
#
#  Objective function:
#  -0.4488818631807877
#  The best solution found:
#  [3.15207215 3.35024895 0.91370123 2.88351973 3.21370269 0.3138578
#  0.98289489 0.09115309]
#
#  Objective function:
#  -0.49934512562648986
#  The best solution found:
#  [2.88033938 1.31892677 3.25424589 3.17721669 0.86093993 0.21703778
#  0.41678931 0.32622099]
#
#  Objective function:
#  -0.5699610247582635
#  The best solution found:
#  [2.60237757 3.56449987 1.67925353 0.54533409 0.43550147 0.40003201
#  0.55274085 0.99241505]
#
#  Objective function:
#  -0.51499064362915
#  The best solution found:
#  [3.26210307 3.84641367 2.5070466  0.14330278 1.52118284 1.62540355
#  0.41771629 0.16474966]
#
# ...

# %%
model=ga(function=f,dimension=n,variable_type='real',variable_boundaries=varbound, algorithm_parameters=algorithm_param)
model.run()
solution=model.output_dict
print(solution['function'])
# Out:
#  The best solution found:
#  [2.0952677  2.97722348 3.16129635 1.17541946 0.80217404 0.7189998
#  0.55169372 0.33230586]
#
#  Objective function:
#  -0.4762479592251295
# ...

# %%
print(best_sol)
# Out:
# -0.4791705526264519

# %%
##(0.1, 400, -0.4791705526264519)

# %%
# best_sols = run_ensemble()
# #
# print(best_sols)

# %%
# algorithm_param = {'max_num_iteration': 10000,\
#                    'population_size':100,\
#                    'mutation_probability':0.1,\
#                    'elit_ratio': 0,\
#                    'crossover_probability': 0.5,\
#                    'parents_portion': 0.3,\
#                    'crossover_type':'uniform',\
#                    'max_iteration_without_improv':3000, \
#                     'convergence_curve': 'False'}

import numpy as np

best_sols = [{'variable': np.array([2.94277191, 2.94517464, 3.10781701, 0.45248744, 1.13210558,
       3.13405853, 0.90337757, 0.48881823]), 'function': -0.45886942482396476}, {'variable': np.array([5.77465368, 3.4940261 , 0.24476459, 2.84956382, 0.4099877 ,
       0.49990203, 0.2885011 , 2.85571689]), 'function': -0.43212819382677203}, {'variable': np.array([6.49205909, 2.56578109, 0.23115496, 2.71018945, 2.97427258,
       0.36552367, 0.53607771, 0.45445925]), 'function': -0.46388317375864946}, {'variable': np.array([0.35636343, 2.8670269 , 3.0733049 , 2.80497166, 1.57072083,
       0.31444411, 3.01140056, 0.45264301]), 'function': -0.4709753194785591}, {'variable': np.array([2.79585452, 3.42792143, 2.29782551, 3.17377329, 3.3210736 ,
       1.33172059, 0.15231888, 0.14917837]), 'function': -0.4548924892758458}, {'variable': np.array([3.32199875, 3.31238304, 0.49041359, 1.39749354, 0.87238512,
       0.4802227 , 0.34714629, 1.56083961]), 'function': -0.49559498767438664}, {'variable': np.array([3.16845016, 3.38477722, 0.05915814, 2.93362176, 0.56695685,
       1.03754196, 0.59209162, 2.469715  ]), 'function': -0.45118112155602164}, {'variable': np.array([3.45972235, 3.2027046 , 3.35473049, 2.97645892, 0.0913583 ,
       0.20361714, 0.38674175, 1.50978986]), 'function': -0.5720855769419053}, {'variable': np.array([0.85332927, 3.55315883, 0.40789312, 2.58098257, 2.86691707,
       0.32938777, 1.18778462, 0.38664624]), 'function': -0.43609590831382106}, {'variable': np.array([3.29856043, 3.4902179 , 2.87957628, 1.70111358, 2.59554317,
       0.32166624, 0.40783557, 0.21977333]), 'function': -0.5350671932596696}, {'variable': np.array([1.24444153, 2.83696029, 3.11767988, 1.28903599, 2.8388265 ,
       0.42508525, 0.05320446, 3.20546601]), 'function': -0.4011572135986841}, {'variable': np.array([3.29942126, 0.35388587, 3.44484416, 3.80320722, 1.72337686,
       0.38096299, 0.46500491, 0.76525526]), 'function': -0.4077643846546526}, {'variable': np.array([2.69414642, 2.16982204, 0.15789961, 3.43227306, 3.52950301,
       0.42333841, 0.4044506 , 0.44537938]), 'function': -0.450107505721575}, {'variable': np.array([2.80739712, 3.26263276, 3.08842705, 3.24498621, 2.6837488 ,
       0.40629519, 2.92395844, 1.17644119]), 'function': -0.406831278161489}, {'variable': np.array([6.50441937, 3.20699591, 0.14299833, 0.39554993, 0.88957207,
       2.67762798, 0.13439965, 2.04333684]), 'function': -0.4402764170196619}, {'variable': np.array([3.38036863, 2.64678558, 0.60939895, 1.85296777, 0.34816491,
       0.67236411, 0.92863714, 0.68247921]), 'function': -0.4910165779136461}, {'variable': np.array([3.44447727, 3.21109985, 1.5718274 , 2.68333498, 0.63193519,
       1.17532618, 0.39709932, 0.18766314]), 'function': -0.5095378732088651}, {'variable': np.array([2.89424676, 3.69408272, 3.65992444, 3.03765386, 2.95043833,
       0.34009469, 0.36192104, 0.28981061]), 'function': -0.4434580300374675}, {'variable': np.array([3.08894738, 3.07288546, 2.92677888, 2.30326029, 3.34002128,
       1.98106106, 0.20125504, 0.4160397 ]), 'function': -0.4449073644496492}, {'variable': np.array([3.06706788, 1.11966221, 2.7820279 , 2.75495853, 3.0696499 ,
       0.09407578, 2.39148919, 0.25155993]), 'function': -0.44649923939692443}, {'variable': np.array([3.26604491, 0.26611583, 3.25505242, 3.02077476, 3.11390188,
       0.1175766 , 0.93991905, 1.98903932]), 'function': -0.450862878827129}, {'variable': np.array([4.15432485, 1.31158221, 2.9011026 , 2.9889464 , 0.26697503,
       0.71462208, 0.19855915, 0.86945998]), 'function': -0.44008408274789085}, {'variable': np.array([0.10817016, 2.95012882, 2.76235116, 3.14762596, 0.23915157,
       0.62052279, 3.21458511, 0.64992145]), 'function': -0.45493307041683984}, {'variable': np.array([3.37641587, 3.06055065, 2.57427669, 0.14645508, 0.4863289 ,
       2.62109789, 2.85095102, 0.75851113]), 'function': -0.42471424400034713}, {'variable': np.array([3.13518787, 0.3543776 , 3.03666513, 3.32328403, 3.57386696,
       0.84866038, 1.93911369, 0.15162832]), 'function': -0.4103324086721954}]

# %%
import numpy as np

function_values = [sol['function'] for sol in best_sols]
average = np.mean(function_values)

print(average)

## (0.1, 100, -0.45573023830946446)
# Out:
# -0.45573023830946446

# %%
# algorithm_param = {'max_num_iteration': 10000,\
#                    'population_size':50,\
#                    'mutation_probability':0.1,\
#                    'elit_ratio': 0,\
#                    'crossover_probability': 0.5,\
#                    'parents_portion': 0.3,\
#                    'crossover_type':'uniform',\
#                    'max_iteration_without_improv':3000, \
#                     'convergence_curve': 'False'}

best_sols = [{'variable': np.array([6.35742682, 0.37917447, 2.85841567, 2.5996402 , 0.15930994,
       0.67749878, 0.57834418, 1.38878332]), 'function': -0.4628663453814132}, {'variable': np.array([3.42461485, 2.85108396, 2.65538679, 1.40804769, 0.46124328,
       0.52302654, 2.94323809, 0.44768004]), 'function': -0.4597652218176646}, {'variable': np.array([2.96809837, 3.18519434, 2.80577935, 0.39741533, 1.33316145,
       0.55287099, 2.35805214, 0.58544185]), 'function': -0.45672800748213155}, {'variable': np.array([6.19171177, 6.18581627, 0.21765037, 2.73464039, 0.49121593,
       2.82887667, 2.01897391, 0.37715879]), 'function': -0.37504307380666907}, {'variable': np.array([2.3281957 , 2.71107062, 3.09865002, 1.49331098, 3.20978418,
       0.25680458, 0.09819114, 1.39640593]), 'function': -0.42401869809828463}, {'variable': np.array([5.83982368, 2.95018674, 0.65274405, 2.73819431, 0.61813954,
       0.5625636 , 0.35532267, 1.09503891]), 'function': -0.4470781805221745}, {'variable': np.array([0.05055501, 3.24229549, 2.64415183, 3.08276955, 1.30257276,
       0.93968302, 0.17871832, 2.96943658]), 'function': -0.4315126751414277}, {'variable': np.array([6.46685965, 2.22437202, 3.10936064, 0.36883651, 0.95196795,
       1.47686318, 0.41591246, 0.42644449]), 'function': -0.42921192481696185}, {'variable': np.array([3.61585975, 3.38862041, 3.13825485, 0.20877933, 2.86995589,
       2.45774616, 0.36451067, 1.03529714]), 'function': -0.4287318068225842}, {'variable': np.array([2.83158688, 3.24711901, 0.24429167, 1.14415319, 3.41678987,
       0.19548299, 0.36061736, 1.22606288]), 'function': -0.5101448773837514}, {'variable': np.array([3.34095679, 3.24155664, 0.41140832, 2.75423434, 1.91465569,
       0.88365617, 1.29595082, 0.41452114]), 'function': -0.42398071794622655}, {'variable': np.array([3.11176159, 3.15064808, 3.26731962, 0.30555887, 0.64435935,
       2.16146758, 0.36075052, 0.351109  ]), 'function': -0.5745638937913369}, {'variable': np.array([3.08544702, 1.74920843, 3.28271122, 0.12515953, 0.62995525,
       0.12097803, 3.14875041, 3.0292985 ]), 'function': -0.4505907136893201}, {'variable': np.array([3.12308265, 3.16789783, 2.56905401, 2.50148545, 1.3617935 ,
       0.97597878, 0.26807158, 0.23299013]), 'function': -0.5002779641249909}, {'variable': np.array([1.43274126, 0.62457437, 3.31752558, 2.96039762, 0.43571511,
       0.11073514, 1.53426247, 1.97951543]), 'function': -0.36418021897930125}, {'variable': np.array([1.86171042, 2.85167265, 0.28453614, 2.77980057, 3.09587083,
       1.12488713, 0.13883318, 0.92149973]), 'function': -0.43039880594073954}, {'variable': np.array([3.60405711, 3.11585154, 3.09610611, 1.65580214, 0.5765853 ,
       0.30835741, 0.39695851, 0.86627509]), 'function': -0.5374474145787}, {'variable': np.array([0.36698076, 3.27265009, 2.75976605, 0.53298517, 3.34385478,
       0.21681749, 2.59297834, 0.62505404]), 'function': -0.43248973457277506}, {'variable': np.array([2.94291213, 0.16790833, 3.17520119, 3.1286116 , 0.75251448,
       2.51505987, 0.46381404, 0.29325873]), 'function': -0.5072430145355952}, {'variable': np.array([3.41660348, 3.35325997, 2.60030484, 0.19212997, 0.37847036,
       1.44399213, 0.47440816, 2.88384078]), 'function': -0.46943279635683655}, {'variable': np.array([2.94343794, 3.08172777, 1.75944543, 2.48145793, 0.20867302,
       2.78014685, 0.83726828, 0.15043772]), 'function': -0.4820440359996043}, {'variable': np.array([6.51663778, 2.85040487, 3.47068807, 0.55857568, 0.52466031,
       0.44568815, 0.51440001, 0.68472256]), 'function': -0.4803586990816174}, {'variable': np.array([3.43065281, 2.83417122, 1.02531536, 1.28019392, 2.36654314,
       0.72408214, 0.56227432, 0.36003616]), 'function': -0.42405679024018367}, {'variable': np.array([3.35807404, 2.88191577, 1.36210606, 2.89378084, 3.00027784,
       3.06985224, 0.75150526, 0.53296745]), 'function': -0.4104512286422078}, {'variable': np.array([5.26333231, 3.16090282, 3.30364982, 0.17918121, 1.43909115,
       1.46733809, 0.27963515, 0.24351671]), 'function': -0.4591278680910658}]

# %%
import numpy as np

function_values = [sol['function'] for sol in best_sols]
average = np.mean(function_values)

print(average)

## (0.1, 50, -0.4548697883137426)
# Out:
# -0.4548697883137426

# %%
# algorithm_param = {'max_num_iteration': 10000,\
#                    'population_size':150,\
#                    'mutation_probability':0.1,\
#                    'elit_ratio': 0,\
#                    'crossover_probability': 0.5,\
#                    'parents_portion': 0.3,\
#                    'crossover_type':'uniform',\
#                    'max_iteration_without_improv':3000, \
#                     'convergence_curve': 'False'}

best_sols = [{'variable': np.array([2.99663174, 3.28047408, 2.71426298, 2.40552035, 0.14741762,
       0.03278173, 2.48413546, 1.12938465]), 'function': -0.4566393138390966}, {'variable': np.array([2.93693471, 3.18577901, 1.19663412, 0.3492718 , 3.04772355,
       3.23306042, 0.11886707, 0.25351041]), 'function': -0.5279277773149877}, {'variable': np.array([3.55135553, 3.29659632, 0.28683002, 0.26733871, 0.55731423,
       0.73462645, 1.67506456, 1.2682003 ]), 'function': -0.4945713367044322}, {'variable': np.array([2.58251913, 2.93294939, 1.45333227, 0.64507081, 2.36074804,
       0.17446086, 0.3777361 , 1.00998034]), 'function': -0.4644903890197188}, {'variable': np.array([3.32139795, 3.2252512 , 2.78999465, 0.59467332, 0.55863675,
       0.38088034, 1.36415172, 1.12121721]), 'function': -0.4924223483092995}, {'variable': np.array([3.7038949 , 2.88974564, 3.54374807, 3.43098592, 1.14993771,
       0.2201331 , 0.51127335, 0.22126816]), 'function': -0.47105578131247167}, {'variable': np.array([3.41123169, 3.37353579, 0.67739775, 3.47391608, 0.76125583,
       0.74780005, 0.28951717, 0.81767274]), 'function': -0.4523842481966941}, {'variable': np.array([3.31406796, 0.25903115, 3.00233383, 3.02379671, 3.0799268 ,
       3.4150835 , 0.39445942, 1.57241349]), 'function': -0.43355907220217016}, {'variable': np.array([3.10339396, 3.23212432, 1.56554603, 2.78139278, 0.1241301 ,
       0.31764788, 0.16207458, 2.92458283]), 'function': -0.5437090656529654}, {'variable': np.array([1.7891498 , 3.34317784, 2.9598582 , 2.71487517, 3.05489141,
       0.31269835, 0.6601497 , 0.1167311 ]), 'function': -0.4943061368279277}, {'variable': np.array([2.93322241, 0.14634384, 2.80585703, 2.6964136 , 0.18267429,
       2.54317838, 2.59635071, 0.22659326]), 'function': -0.45600692065740017}, {'variable': np.array([2.98087652, 1.18512016, 3.42790353, 0.10199355, 2.71813505,
       3.10322308, 0.45986043, 0.70083168]), 'function': -0.4428851083009417}, {'variable': np.array([3.24632321, 3.62258025, 0.2625796 , 0.40554713, 1.98949009,
       0.87723946, 1.94872164, 0.20561826]), 'function': -0.4557649033425126}, {'variable': np.array([3.35668811, 3.05479734, 0.41964731, 0.95804241, 0.63961674,
       2.96316122, 0.16405324, 1.08934875]), 'function': -0.5015402445498376}, {'variable': np.array([2.39406224, 3.25571908, 3.50503318, 0.32025754, 0.31525789,
       1.33002628, 0.40996205, 0.68308544]), 'function': -0.5254601236035911}, {'variable': np.array([3.0257021 , 3.12770756, 2.97899874, 2.76800331, 1.95792498,
       0.33613933, 2.76523175, 0.04097237]), 'function': -0.4791771628473339}, {'variable': np.array([3.12460865, 6.10326051, 1.52847576, 0.3681206 , 3.14445956,
       0.14418901, 0.68646905, 0.29989344]), 'function': -0.48455025927692547}, {'variable': np.array([1.37394606, 3.16239347, 3.16849407, 2.75555138, 1.27335251,
       0.57160211, 0.3955212 , 0.349612  ]), 'function': -0.48802784281441314}, {'variable': np.array([6.09069704, 3.26647663, 1.12991371, 3.35675161, 0.56066172,
       0.14317625, 0.97693748, 0.39256746]), 'function': -0.4697914874171832}, {'variable': np.array([3.4760483 , 2.5140192 , 3.88759345, 3.50451258, 0.18559614,
       0.268774  , 0.45331424, 0.69822077]), 'function': -0.43266468215537013}, {'variable': np.array([3.33642115, 2.64090629, 1.15330386, 0.89374257, 1.27831851,
       0.35031023, 0.36048246, 0.62927195]), 'function': -0.5462946613805046}, {'variable': np.array([3.37829741, 2.19142331, 3.13658256, 3.22219202, 1.64186939,
       0.08371488, 0.24620012, 0.8936502 ]), 'function': -0.4733411139201962}, {'variable': np.array([3.27503156, 2.34703923, 0.38713553, 1.14022536, 2.97672136,
       0.76706089, 0.29986135, 0.46104766]), 'function': -0.5234887899098294}, {'variable': np.array([3.60390522, 3.56374862, 0.7912524 , 2.94798623, 0.70726218,
       0.26271814, 0.85419536, 0.19083155]), 'function': -0.5129077052471658}, {'variable': np.array([3.42404481, 3.47760336, 2.05005066, 0.12988834, 0.69631536,
       0.61945956, 1.51069463, 0.41063897]), 'function': -0.4936787944334606}]

# %%
import numpy as np

function_values = [sol['function'] for sol in best_sols]
average = np.mean(function_values)

print(average)

## (0.1, 150, -0.48466581076945714)
# Out:
# -0.48466581076945714

# %%
# algorithm_param = {'max_num_iteration': 10000,\
#                    'population_size':200,\
#                    'mutation_probability':0.1,\
#                    'elit_ratio': 0,\
#                    'crossover_probability': 0.5,\
#                    'parents_portion': 0.3,\
#                    'crossover_type':'uniform',\
#                    'max_iteration_without_improv':3000, \
#                     'convergence_curve': 'False'}

best_sols = [{'variable': np.array([2.61684859, 3.35768209, 2.68674084, 3.2032328 , 0.71177344,
       0.19442439, 0.16865506, 1.02855888]), 'function': -0.5132089279453235}, {'variable': np.array([2.58848637, 2.70973753, 3.52381031, 2.64111551, 0.22557789,
       0.32195337, 0.49795979, 0.81489103]), 'function': -0.49611208798121254}, {'variable': np.array([2.92770702, 2.98281697, 0.13582377, 1.74411541, 3.13070036,
       0.33050173, 2.96287001, 0.56760753]), 'function': -0.4892269244278254}, {'variable': np.array([3.37855383, 2.71544282, 2.92864748, 1.48350863, 0.54776926,
       1.99983638, 0.06982243, 0.35618915]), 'function': -0.5154753778001963}, {'variable': np.array([3.21318568, 0.44799462, 3.30055702, 0.30276574, 3.1617698 ,
       1.57895114, 0.32047449, 3.11547011]), 'function': -0.4561725439197587}, {'variable': np.array([3.02014801, 3.14649055, 2.72184289, 3.04132343, 0.62655702,
       0.45775681, 0.40341092, 0.54558714]), 'function': -0.5587657319113863}, {'variable': np.array([3.54603924, 3.22953118, 2.83904116, 0.29644313, 3.2015441 ,
       1.63391789, 3.37315001, 0.33653004]), 'function': -0.42141200388999595}, {'variable': np.array([3.78477967, 3.12085972, 3.22307652, 2.92318318, 0.26648604,
       1.0349046 , 0.59650125, 0.1163708 ]), 'function': -0.5261646451267679}, {'variable': np.array([6.34325708, 2.95638694, 1.07989491, 3.20208127, 0.13062118,
       0.11417269, 0.32401822, 3.13345647]), 'function': -0.4707076583068232}, {'variable': np.array([2.13836013, 0.43437014, 3.06439293, 2.24570634, 3.22440861,
       2.98979973, 0.21171656, 0.11461179]), 'function': -0.4405625880221009}, {'variable': np.array([3.16649435, 2.70243255, 2.99665118, 2.03974521, 0.45766492,
       0.41317499, 0.45745825, 1.07065689]), 'function': -0.5204062657598432}, {'variable': np.array([3.29057069, 2.84174936, 2.43248069, 0.72197555, 1.50289044,
       0.5050396 , 0.46679014, 0.34893163]), 'function': -0.5632041613395977}, {'variable': np.array([3.98726505, 3.08198853, 0.55128734, 0.66795816, 3.14325221,
       0.42083427, 0.23529617, 0.60684771]), 'function': -0.5155048334825698}, {'variable': np.array([3.18491639, 2.38143215, 2.96370283, 0.17398724, 0.58333179,
       2.52670355, 1.37555922, 0.18106703]), 'function': -0.49664040997768316}, {'variable': np.array([0.19621533, 3.28815087, 2.73490646, 2.70136198, 1.43470447,
       0.25919932, 0.20652575, 2.8983927 ]), 'function': -0.481201513357408}, {'variable': np.array([3.06002296, 3.28118963, 2.85694025, 0.25455455, 2.5114277 ,
       3.22639344, 0.28528785, 0.04603545]), 'function': -0.48371391632517685}, {'variable': np.array([2.95207301, 3.29843456, 2.76381374, 3.13967432, 0.15649729,
       0.55567961, 0.85812688, 0.3372612 ]), 'function': -0.5617135120070067}, {'variable': np.array([1.50358695, 2.98883434, 3.33011817, 3.13181736, 0.34522199,
       0.39884459, 0.14639348, 1.71287798]), 'function': -0.4927758102531758}, {'variable': np.array([3.24679687, 2.70290662, 0.8318208 , 3.48403417, 0.73241449,
       0.49105168, 0.30541202, 0.44591316]), 'function': -0.5334779546879379}, {'variable': np.array([3.42914292, 2.50950846, 0.27005994, 2.00929828, 3.08536075,
       0.15572975, 0.88363067, 0.61065774]), 'function': -0.4744228651365116}, {'variable': np.array([3.12848331, 2.83303663, 0.29835032, 1.55939935, 0.38203725,
       1.15336762, 3.2556614 , 0.29760588]), 'function': -0.47911583635752897}, {'variable': np.array([3.27373599, 3.19823582, 1.64780099, 0.11913751, 2.78676347,
       0.81763662, 0.70396266, 0.41734089]), 'function': -0.5311892161768847}, {'variable': np.array([3.098327  , 0.36180098, 3.01090687, 1.77852039, 2.98727397,
       0.35574719, 0.24242915, 1.79674095]), 'function': -0.48503175370152246}, {'variable': np.array([3.53879838, 3.0176803 , 0.04112557, 0.24350392, 3.00035497,
       2.9588728 , 1.97386467, 0.57173473]), 'function': -0.46351384927543504}, {'variable': np.array([3.10669225, 3.16988213, 0.1130098 , 1.58334259, 3.37281676,
       0.70716586, 0.21573911, 0.87778976]), 'function': -0.5123319651435201}]

# %%
import numpy as np

function_values = [sol['function'] for sol in best_sols]
average = np.mean(function_values)

print(average)

## (0.1, 200, -0.4992820940925277)
# Out:
# -0.4992820940925277

# %% [markdown]
# Mutation Probability 0.01, 0.05, 0.15, 0.3

# %%
import numpy as np
from geneticalgorithm import geneticalgorithm as ga
import math

def f(X):
    """Keane's Bump function.
    n = dimension of the domain
    x = vector in the domain"""
    cos4 = 0
    cos2 = 1
    x_i = 0
    n = len(X)
    for i in range(n):
        cos4 += math.cos(X[i])**4
        cos2 *= math.cos(X[i])**2
        x_i += (i+1)*(X[i]**2)
    if x_i == 0:
        answer = None
    else:
        answer = np.abs((cos4 - 2*cos2)/math.sqrt(x_i))
    ## we are turning the maximization problem into a minimization problem
    objective = -1 * answer
    ## we are adding a penalty for the constraint if either is violated!
    if np.sum(X) > 15 * len(X) / 2 or np.prod(X) < 0.75:
        ## penalty has to be larger than objective function value
        penalty = 2
    else:
        penalty = 0
    return objective + penalty

## 8D case
n = 8

varbound=np.array([[0,10]]*n)

algorithm_param = {'max_num_iteration': 10000,\
                   'population_size':200,\
                   'mutation_probability':0.1,\
                   'elit_ratio': 0,\
                   'crossover_probability': 0.5,\
                   'parents_portion': 0.3,\
                   'crossover_type':'uniform',\
                   'max_iteration_without_improv':3000, \
                    'convergence_curve': 'False'}

def run_ensemble():
    best_sols = []
    for i in range(25):
        model=ga(function=f,dimension=n,variable_type='real',variable_boundaries=varbound, algorithm_parameters=algorithm_param)
        model.run()
        solution=model.output_dict
        print(solution)
        best_sols.append(solution)
    return best_sols

# %%
mutation_prob = [0.01, 0.05, 0.1, 0.3, 0.5]
population_size = [50, 100, 150, 200, 400]

def run_ensemble():
    best_sols = []
    for i in range(25):
        model=ga(function=f,dimension=n,variable_type='real',variable_boundaries=varbound, algorithm_parameters=algorithm_param)
        model.run()
        solution=model.output_dict
        print(solution)
        best_sols.append(solution['function'])
    return np.average(best_sols)


results = []
for m in mutation_prob:
    for p in population_size:
        algorithm_param = {'max_num_iteration': 10000,\
                   'population_size':p,\
                   'mutation_probability':m,\
                   'elit_ratio': 0,\
                   'crossover_probability': 0.5,\
                   'parents_portion': 0.3,\
                   'crossover_type':'uniform',\
                   'max_iteration_without_improv':3000, \
                    'convergence_curve': False}
        best_sol = run_ensemble()
        results.append([m, p, best_sol])
print(results)
