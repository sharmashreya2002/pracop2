# %%
import numpy as np
import math

rng1 = np.random.default_rng(seed=0)

def objective_function(x):
    """Keane's Bump function.
    n = dimension of the domain
    x = vector in the domain"""
    cos4 = 0
    cos2 = 1
    x_i = 0
    n = len(x)
    for i in range(n):
        cos4 += math.cos(x[i])**4
        cos2 *= math.cos(x[i])**2
        x_i += (i+1)*(x[i]**2)
    if x_i == 0:
        answer = None
    else:
        answer = np.abs((cos4 - 2*cos2)/math.sqrt(x_i))
    ## we are turning the maximization problem into a minimization problem
    return -1 * answer

def update_D(D, R):
    D =  0.9 * D + 0.21 * R
    min_step_size = 1e-3
    max_step_size = 1
    D = np.where(D < min_step_size, min_step_size, D)
    D = np.where(D > max_step_size, max_step_size, D)
    return D

def decrement_temperature(T, alpha):
    return T*alpha

def decrement_temperature_huang(T, accepted_solutions_at_T):
    alpha = max(0.5, np.exp(- 0.7 * T / np.std(accepted_solutions_at_T)))
    return T*alpha

def proposal(x, D, rng): ## Parks 1991
    while True:
        u = rng.uniform(-1, 1, size=len(x))
        x_new = x + np.dot(D, u)
        if np.all((x_new > 0) & (x_new < 10)):
            if np.sum(x_new) < 15 * len(x) / 2 and np.prod(x_new) > 0.75:
                break
    return x_new, u

def archive_function(x, archive, unchanged_counter):
    ## 10 best solutions 
    archive_limit = 10
    f = objective_function(x)
    if len(archive) < archive_limit:
        archive.append((x, f))
    else:
        archive.append((x, f))  # Update all elements
        archive.sort(key=lambda item: item[1])  # Sort the archive by objective function value
        archive = archive[:archive_limit]  # Keep only the top elements
    if np.array_equal(archive[0][0],x): ## if current solution is the best solution in archive, reset counter
        unchanged_counter = 0
    else:
        unchanged_counter += 1
    return archive, unchanged_counter

def find_Tin_White(Lk, n, rng): ## White 1984
    Tin = []
    for i in range(25):
        while True:
            x = np.random.uniform(0, 10, size=n)
            if np.all((x > 0) & (x < 10)):
                if np.sum(x) < 15 * n / 2 and np.prod(x) > 0.75:
                    break
        D = np.identity(n)
        acceptanced_objectives = []
        for j in range(Lk):
            u = rng.uniform(-1, 1, size=n)
            x_new = x + np.dot(D, u)
            delta = objective_function(x_new) - objective_function(x)
            R = np.abs(np.diag(np.dot(D, u)))
            acceptanced_objectives.append(delta)
            x = x_new
            D = update_D(D, R)
        Tin.append(np.std(acceptanced_objectives))
    return np.average(Tin)

def find_Tin_kirkpatrick(Lk, n, rng): ## Kirkpatrick 1984
    Tin = []
    for i in range(50):
        while True:
            x = np.random.uniform(0, 10, size=n)
            if np.all((x > 0) & (x < 10)):
                if np.sum(x) < 15 * n / 2 and np.prod(x) > 0.75:
                    break
        D = np.identity(n)
        accepted_deltas = []
        for j in range(Lk):
            u = rng.uniform(-1, 1, size=n)
            x_new = x + np.dot(D, u)
            delta = objective_function(x_new) - objective_function(x)
            R = np.abs(np.diag(np.dot(D, u)))
            if delta > 0:
                accepted_deltas.append(delta)
            x = x_new
            D = update_D(D, R)
        Tin.append(-1 * np.sum(accepted_deltas) / math.log(0.8))
    return np.average(Tin)

def main(x0, Lk, rng):
    x_prev = x0
    # T = find_Tin_White(Lk, len(x0), rng)
    T = find_Tin_kirkpatrick(Lk, len(x0), rng)
    print(f"Initial temperature: {T}")
    Din = np.identity(len(x0))
    D = Din
    accepted_solutions = []
    archive = []
    counter =  0
    max_iter = 15000
    alpha = 0.95
    unchanged_counter = 0
    unchanged_threshold = 5000
    while counter < max_iter and unchanged_counter < unchanged_threshold:
        acceptances_at_T = 0
        accepted_solutions_at_T = []
        for i in range(Lk):
            x_new, u = proposal(x_prev, Din, rng)
            counter += 1
            R = np.abs(np.diag(np.dot(D, u)))
            delta = objective_function(x_new) - objective_function(x_prev)
            if delta < 0:
                x_prev = x_new
                acceptances_at_T += 1
                accepted_solutions.append(x_new)
                accepted_solutions_at_T.append(x_new)
                D = update_D(D, R)
                archive, unchanged_counter = archive_function(x_new, archive, unchanged_counter)
            else:
                step_size = np.sqrt(np.sum(R**2))
                p = np.exp(- (0.7 * delta) / (T * step_size))
                if rng.uniform() < p:
                    x_prev = x_new
                    acceptances_at_T += 1
                    accepted_solutions.append(x_new)
                    accepted_solutions_at_T.append(x_new)
                    D = update_D(D, R)
                    archive, unchanged_counter = archive_function(x_new, archive, unchanged_counter)
                else:
                    unchanged_counter += 1
            if acceptances_at_T / Lk >= 0.6:
                break
        # T = decrement_temperature(T, alpha)
        T = decrement_temperature_huang(T, accepted_solutions_at_T)
        print(f"New temperature: {T}, acceptances at previous T: {acceptances_at_T/ Lk}, counter: {counter}")
    return accepted_solutions, archive

# %%
n = 8 ## 2D
while True:
    x = np.random.uniform(0, 10, size=n)
    if np.all((x > 0) & (x < 10)):
        if np.sum(x) < 15 * n / 2 and np.prod(x) > 0.75:
            break
accepted_solutions, archive = main(x, 75, rng1)
# Out:
# Initial temperature: 4.023199373938333
# New temperature: 2.0115996869691664, acceptances at previous T: 0.6, counter: 46
# New temperature: 1.1684552144086635, acceptances at previous T: 0.6, counter: 91
# New temperature: 0.857829713593691, acceptances at previous T: 0.6, counter: 136
# New temperature: 0.6843714735117645, acceptances at previous T: 0.6, counter: 181
# New temperature: 0.5833577440819744, acceptances at previous T: 0.6, counter: 226
# New temperature: 0.5089588615906756, acceptances at previous T: 0.6, counter: 274
# New temperature: 0.4334188554057123, acceptances at previous T: 0.6, counter: 319
# New temperature: 0.378603975979273, acceptances at previous T: 0.6, counter: 366
# New temperature: 0.333918994263775, acceptances at previous T: 0.6, counter: 413
# New temperature: 0.30250636070237913, acceptances at previous T: 0.6, counter: 459
# New temperature: 0.2749720899618355, acceptances at previous T: 0.6, counter: 504
# New temperature: 0.25231507675525394, acceptances at previous T: 0.6, counter: 549
# New temperature: 0.23811860282889896, acceptances at previous T: 0.6, counter: 597
# New temperature: 0.22355195717208032, acceptances at previous T: 0.6, counter: 644
# New temperature: 0.20829910399145826, acceptances at previous T: 0.6, counter: 691
# New temperature: 0.19590491818344558, acceptances at previous T: 0.6, counter: 738
# New temperature: 0.18244341627166502, acceptances at previous T: 0.6, counter: 788
# New temperature: 0.17095340843189913, acceptances at previous T: 0.6, counter: 836
# New temperature: 0.1637817103074503, acceptances at previous T: 0.6, counter: 882
# New temperature: 0.15649331507431577, acceptances at previous T: 0.6, counter: 930
# New temperature: 0.14932030751980158, acceptances at previous T: 0.6, counter: 978
# New temperature: 0.14380926605319616, acceptances at previous T: 0.6, counter: 1029
# New temperature: 0.13789612423121947, acceptances at previous T: 0.6, counter: 1091
# New temperature: 0.13308211067938505, acceptances at previous T: 0.6, counter: 1141
# New temperature: 0.12782171342850793, acceptances at previous T: 0.6, counter: 1191
# New temperature: 0.12322779746438878, acceptances at previous T: 0.6, counter: 1238
# New temperature: 0.11969541337596494, acceptances at previous T: 0.6, counter: 1286
# New temperature: 0.11629028401031331, acceptances at previous T: 0.6, counter: 1342
# New temperature: 0.11285681026351391, acceptances at previous T: 0.6, counter: 1393
# New temperature: 0.10983744005652607, acceptances at previous T: 0.6, counter: 1449
# New temperature: 0.10643177138966414, acceptances at previous T: 0.6, counter: 1504
# New temperature: 0.10354748077410465, acceptances at previous T: 0.6, counter: 1554
# New temperature: 0.10029426431030519, acceptances at previous T: 0.6, counter: 1610
# New temperature: 0.09738992661305955, acceptances at previous T: 0.6, counter: 1660
# New temperature: 0.094985602209943, acceptances at previous T: 0.6, counter: 1707
# New temperature: 0.09217203973709381, acceptances at previous T: 0.6, counter: 1760
# New temperature: 0.0898306800338784, acceptances at previous T: 0.6, counter: 1813
# New temperature: 0.0876989810176752, acceptances at previous T: 0.6, counter: 1865
# New temperature: 0.0856186364871523, acceptances at previous T: 0.6, counter: 1920
# New temperature: 0.08343778468831622, acceptances at previous T: 0.6, counter: 1971
# New temperature: 0.08173802557329361, acceptances at previous T: 0.6, counter: 2024
# New temperature: 0.07981595308580279, acceptances at previous T: 0.6, counter: 2078
# New temperature: 0.07746622572636985, acceptances at previous T: 0.6, counter: 2136
# New temperature: 0.07593276660713782, acceptances at previous T: 0.6, counter: 2192
# New temperature: 0.07444495167374529, acceptances at previous T: 0.6, counter: 2251
# New temperature: 0.07271162613443019, acceptances at previous T: 0.6, counter: 2302
# New temperature: 0.07116007647262562, acceptances at previous T: 0.6, counter: 2361
# New temperature: 0.06975986947824679, acceptances at previous T: 0.6, counter: 2412
# New temperature: 0.06852933062486065, acceptances at previous T: 0.6, counter: 2468
# New temperature: 0.06745679084395027, acceptances at previous T: 0.6, counter: 2524
# New temperature: 0.06610643848902988, acceptances at previous T: 0.6, counter: 2576
# New temperature: 0.06493178759512651, acceptances at previous T: 0.6, counter: 2631
# New temperature: 0.06380288645431992, acceptances at previous T: 0.6, counter: 2686
# New temperature: 0.06265672737866228, acceptances at previous T: 0.6, counter: 2737
# New temperature: 0.061636357502232786, acceptances at previous T: 0.6, counter: 2799
# New temperature: 0.0604350055580236, acceptances at previous T: 0.6, counter: 2853
# New temperature: 0.05951884498784608, acceptances at previous T: 0.6, counter: 2908
# New temperature: 0.05871187211900207, acceptances at previous T: 0.6, counter: 2957
# New temperature: 0.05790327090424675, acceptances at previous T: 0.6, counter: 3010
# New temperature: 0.05707805688093331, acceptances at previous T: 0.6, counter: 3067
# New temperature: 0.05629267238821483, acceptances at previous T: 0.6, counter: 3121
# New temperature: 0.055470818439232544, acceptances at previous T: 0.6, counter: 3178
# New temperature: 0.05436862588458943, acceptances at previous T: 0.6, counter: 3227
# New temperature: 0.0533232901452687, acceptances at previous T: 0.6, counter: 3279
# New temperature: 0.05252364030280639, acceptances at previous T: 0.6, counter: 3339
# New temperature: 0.05175132677414902, acceptances at previous T: 0.6, counter: 3398
# New temperature: 0.051111781227863605, acceptances at previous T: 0.6, counter: 3456
# New temperature: 0.050385257778367866, acceptances at previous T: 0.6, counter: 3513
# New temperature: 0.049638651261791546, acceptances at previous T: 0.6, counter: 3563
# New temperature: 0.04891212163673567, acceptances at previous T: 0.56, counter: 3638
# New temperature: 0.04828273004933873, acceptances at previous T: 0.6, counter: 3690
# New temperature: 0.04764355032495112, acceptances at previous T: 0.5066666666666667, counter: 3765
# New temperature: 0.047090096431054794, acceptances at previous T: 0.5466666666666666, counter: 3840
# New temperature: 0.04625763138797067, acceptances at previous T: 0.3466666666666667, counter: 3915
# New temperature: 0.045480846268913404, acceptances at previous T: 0.4666666666666667, counter: 3990
# New temperature: 0.04494840210029861, acceptances at previous T: 0.6, counter: 4065
# New temperature: 0.04443621522060291, acceptances at previous T: 0.44, counter: 4140
# New temperature: 0.04395652045873247, acceptances at previous T: 0.4, counter: 4215
# New temperature: 0.04324773300260916, acceptances at previous T: 0.4, counter: 4290
# New temperature: 0.0422665924472096, acceptances at previous T: 0.22666666666666666, counter: 4365
# New temperature: 0.041677872677639456, acceptances at previous T: 0.38666666666666666, counter: 4440
# New temperature: 0.04124967883061975, acceptances at previous T: 0.10666666666666667, counter: 4515
# New temperature: 0.04077788136196018, acceptances at previous T: 0.6, counter: 4590
# New temperature: 0.04039183276572624, acceptances at previous T: 0.44, counter: 4665
# New temperature: 0.03998253260598047, acceptances at previous T: 0.5066666666666667, counter: 4740
# New temperature: 0.0396062730571475, acceptances at previous T: 0.4533333333333333, counter: 4815
# New temperature: 0.03926143430363472, acceptances at previous T: 0.41333333333333333, counter: 4890
# New temperature: 0.0387541520580271, acceptances at previous T: 0.6, counter: 4961
# New temperature: 0.038151704800287844, acceptances at previous T: 0.32, counter: 5036
# New temperature: 0.03769967725600408, acceptances at previous T: 0.4, counter: 5111
# New temperature: 0.03727546599858387, acceptances at previous T: 0.5333333333333333, counter: 5186
# New temperature: 0.03687313266389361, acceptances at previous T: 0.6, counter: 5259
# New temperature: 0.03649384383739802, acceptances at previous T: 0.56, counter: 5334
# New temperature: 0.03616425785388331, acceptances at previous T: 0.5333333333333333, counter: 5409
# New temperature: 0.035843490926626954, acceptances at previous T: 0.6, counter: 5480
# New temperature: 0.035536664536271516, acceptances at previous T: 0.6, counter: 5540
# New temperature: 0.03523705351265149, acceptances at previous T: 0.6, counter: 5606
# New temperature: 0.03492177184400053, acceptances at previous T: 0.6, counter: 5681
# New temperature: 0.03459126013762058, acceptances at previous T: 0.4, counter: 5756
# New temperature: 0.034284567038151664, acceptances at previous T: 0.5466666666666666, counter: 5831
# New temperature: 0.03396241309810249, acceptances at previous T: 0.52, counter: 5906
# New temperature: 0.033562135459551355, acceptances at previous T: 0.32, counter: 5981
# New temperature: 0.03324324258963146, acceptances at previous T: 0.4266666666666667, counter: 6056
# New temperature: 0.03289736021534792, acceptances at previous T: 0.6, counter: 6128
# New temperature: 0.03260246413677871, acceptances at previous T: 0.5466666666666666, counter: 6203
# New temperature: 0.03232062867018993, acceptances at previous T: 0.2, counter: 6278
# New temperature: 0.03200521430803058, acceptances at previous T: 0.18666666666666668, counter: 6353
# New temperature: 0.031665002546476466, acceptances at previous T: 0.32, counter: 6428
# New temperature: 0.031190976594581588, acceptances at previous T: 0.3466666666666667, counter: 6503
# New temperature: 0.03061669579190053, acceptances at previous T: 0.05333333333333334, counter: 6578
# New temperature: 0.030148511889185516, acceptances at previous T: 0.14666666666666667, counter: 6653
# New temperature: 0.029603142801070025, acceptances at previous T: 0.02666666666666667, counter: 6728
# New temperature: 0.02911286294437819, acceptances at previous T: 0.013333333333333334, counter: 6803
# New temperature: 0.028591030348995593, acceptances at previous T: 0.05333333333333334, counter: 6878
# New temperature: 0.028064280446272124, acceptances at previous T: 0.06666666666666667, counter: 6953
# New temperature: 0.027577840128133874, acceptances at previous T: 0.02666666666666667, counter: 7028
# New temperature: 0.027119506141493027, acceptances at previous T: 0.09333333333333334, counter: 7103
# New temperature: 0.02671171944527738, acceptances at previous T: 0.013333333333333334, counter: 7178
# New temperature: 0.02631100595485713, acceptances at previous T: 0.13333333333333333, counter: 7253
# New temperature: 0.025901962872767817, acceptances at previous T: 0.02666666666666667, counter: 7328
# New temperature: 0.02547037010258471, acceptances at previous T: 0.02666666666666667, counter: 7403
# New temperature: 0.02510316265390792, acceptances at previous T: 0.02666666666666667, counter: 7478
# New temperature: 0.02475890430004567, acceptances at previous T: 0.02666666666666667, counter: 7553
# New temperature: 0.024398086488532502, acceptances at previous T: 0.02666666666666667, counter: 7628
# New temperature: 0.012199043244266251, acceptances at previous T: 0.0, counter: 7703
# New temperature: 0.0060995216221331255, acceptances at previous T: 0.0, counter: 7778
# New temperature: 0.006077787660366492, acceptances at previous T: 0.013333333333333334, counter: 7853
# New temperature: 0.003038893830183246, acceptances at previous T: 0.0, counter: 7928
# New temperature: 0.0030340725408966427, acceptances at previous T: 0.013333333333333334, counter: 8003
# New temperature: 0.0030284788144021085, acceptances at previous T: 0.013333333333333334, counter: 8078
# New temperature: 0.0015142394072010542, acceptances at previous T: 0.0, counter: 8153
# New temperature: 0.0007571197036005271, acceptances at previous T: 0.0, counter: 8228
# New temperature: 0.00037855985180026356, acceptances at previous T: 0.0, counter: 8303
# New temperature: 0.00018927992590013178, acceptances at previous T: 0.0, counter: 8378
# New temperature: 9.463996295006589e-05, acceptances at previous T: 0.0, counter: 8453
# New temperature: 4.7319981475032945e-05, acceptances at previous T: 0.0, counter: 8528
# New temperature: 2.3659990737516473e-05, acceptances at previous T: 0.0, counter: 8603
# New temperature: 1.1829995368758236e-05, acceptances at previous T: 0.0, counter: 8678
# New temperature: 5.914997684379118e-06, acceptances at previous T: 0.0, counter: 8753
# New temperature: 2.957498842189559e-06, acceptances at previous T: 0.0, counter: 8828
# New temperature: 1.4787494210947795e-06, acceptances at previous T: 0.0, counter: 8903
# New temperature: 1.478748220091176e-06, acceptances at previous T: 0.013333333333333334, counter: 8978
# New temperature: 7.39374110045588e-07, acceptances at previous T: 0.0, counter: 9053
# New temperature: 7.39373812145284e-07, acceptances at previous T: 0.013333333333333334, counter: 9128
# New temperature: 3.69686906072642e-07, acceptances at previous T: 0.0, counter: 9203
# New temperature: 1.84843453036321e-07, acceptances at previous T: 0.0, counter: 9278
# New temperature: 9.24217265181605e-08, acceptances at previous T: 0.0, counter: 9353
# New temperature: 4.621086325908025e-08, acceptances at previous T: 0.0, counter: 9428
# New temperature: 2.3105431629540125e-08, acceptances at previous T: 0.0, counter: 9503
# New temperature: 1.1552715814770062e-08, acceptances at previous T: 0.0, counter: 9578
# New temperature: 5.776357907385031e-09, acceptances at previous T: 0.0, counter: 9653
# New temperature: 2.8881789536925156e-09, acceptances at previous T: 0.0, counter: 9728
# New temperature: 2.88817894896423e-09, acceptances at previous T: 0.013333333333333334, counter: 9803
# New temperature: 1.444089474482115e-09, acceptances at previous T: 0.0, counter: 9878
# New temperature: 7.220447372410575e-10, acceptances at previous T: 0.0, counter: 9953
# New temperature: 3.6102236862052875e-10, acceptances at previous T: 0.0, counter: 10028
# New temperature: 1.8051118431026438e-10, acceptances at previous T: 0.0, counter: 10103
# New temperature: 9.025559215513219e-11, acceptances at previous T: 0.0, counter: 10178
# New temperature: 4.5127796077566094e-11, acceptances at previous T: 0.0, counter: 10253
# New temperature: 2.2563898038783047e-11, acceptances at previous T: 0.0, counter: 10328
# New temperature: 1.1281949019391523e-11, acceptances at previous T: 0.0, counter: 10403
# New temperature: 5.640974509695762e-12, acceptances at previous T: 0.0, counter: 10478
# New temperature: 2.820487254847881e-12, acceptances at previous T: 0.0, counter: 10553
# New temperature: 1.4102436274239404e-12, acceptances at previous T: 0.0, counter: 10628
# New temperature: 7.051218137119702e-13, acceptances at previous T: 0.0, counter: 10703
# New temperature: 3.525609068559851e-13, acceptances at previous T: 0.0, counter: 10778
# New temperature: 1.7628045342799255e-13, acceptances at previous T: 0.0, counter: 10853
# New temperature: 8.814022671399628e-14, acceptances at previous T: 0.0, counter: 10928
# New temperature: 4.407011335699814e-14, acceptances at previous T: 0.0, counter: 11003
# New temperature: 2.203505667849907e-14, acceptances at previous T: 0.0, counter: 11078
# New temperature: 1.1017528339249535e-14, acceptances at previous T: 0.0, counter: 11153
# New temperature: 5.508764169624767e-15, acceptances at previous T: 0.0, counter: 11228
# New temperature: 2.7543820848123837e-15, acceptances at previous T: 0.0, counter: 11303
# New temperature: 1.3771910424061918e-15, acceptances at previous T: 0.0, counter: 11378
# New temperature: 6.885955212030959e-16, acceptances at previous T: 0.0, counter: 11453
# New temperature: 3.4429776060154796e-16, acceptances at previous T: 0.0, counter: 11528
# New temperature: 1.7214888030077398e-16, acceptances at previous T: 0.0, counter: 11603
# New temperature: 8.607444015038699e-17, acceptances at previous T: 0.0, counter: 11678
# New temperature: 4.3037220075193495e-17, acceptances at previous T: 0.0, counter: 11753
# New temperature: 2.1518610037596747e-17, acceptances at previous T: 0.0, counter: 11828
# New temperature: 1.0759305018798374e-17, acceptances at previous T: 0.0, counter: 11903
# New temperature: 5.379652509399187e-18, acceptances at previous T: 0.0, counter: 11978
# New temperature: 5.379652509399187e-18, acceptances at previous T: 0.013333333333333334, counter: 12053
# New temperature: 2.6898262546995934e-18, acceptances at previous T: 0.0, counter: 12128
# New temperature: 1.3449131273497967e-18, acceptances at previous T: 0.0, counter: 12203
# New temperature: 6.724565636748984e-19, acceptances at previous T: 0.0, counter: 12278
# New temperature: 3.362282818374492e-19, acceptances at previous T: 0.0, counter: 12353
# New temperature: 1.681141409187246e-19, acceptances at previous T: 0.0, counter: 12428
# New temperature: 8.40570704593623e-20, acceptances at previous T: 0.0, counter: 12503
# New temperature: 8.40570704593623e-20, acceptances at previous T: 0.013333333333333334, counter: 12578
# New temperature: 4.202853522968115e-20, acceptances at previous T: 0.0, counter: 12653
# New temperature: 2.1014267614840574e-20, acceptances at previous T: 0.0, counter: 12728
# New temperature: 1.0507133807420287e-20, acceptances at previous T: 0.0, counter: 12803
# New temperature: 5.2535669037101434e-21, acceptances at previous T: 0.0, counter: 12878
# New temperature: 2.6267834518550717e-21, acceptances at previous T: 0.0, counter: 12953
# New temperature: 1.3133917259275358e-21, acceptances at previous T: 0.0, counter: 13028
# New temperature: 6.566958629637679e-22, acceptances at previous T: 0.0, counter: 13103
# New temperature: 3.2834793148188396e-22, acceptances at previous T: 0.0, counter: 13178
# New temperature: 1.6417396574094198e-22, acceptances at previous T: 0.0, counter: 13253
# New temperature: 8.208698287047099e-23, acceptances at previous T: 0.0, counter: 13328
# New temperature: 4.1043491435235495e-23, acceptances at previous T: 0.0, counter: 13403
# New temperature: 2.0521745717617748e-23, acceptances at previous T: 0.0, counter: 13478
# New temperature: 1.0260872858808874e-23, acceptances at previous T: 0.0, counter: 13553
# New temperature: 5.130436429404437e-24, acceptances at previous T: 0.0, counter: 13628
# New temperature: 2.5652182147022184e-24, acceptances at previous T: 0.0, counter: 13703
# New temperature: 1.2826091073511092e-24, acceptances at previous T: 0.0, counter: 13778
# New temperature: 6.413045536755546e-25, acceptances at previous T: 0.0, counter: 13853
# New temperature: 3.206522768377773e-25, acceptances at previous T: 0.0, counter: 13928
# New temperature: 1.6032613841888865e-25, acceptances at previous T: 0.0, counter: 14003
# New temperature: 8.016306920944433e-26, acceptances at previous T: 0.0, counter: 14078
# New temperature: 4.0081534604722163e-26, acceptances at previous T: 0.0, counter: 14153
# New temperature: 2.0040767302361082e-26, acceptances at previous T: 0.0, counter: 14228
# New temperature: 1.0020383651180541e-26, acceptances at previous T: 0.0, counter: 14303
# New temperature: 5.0101918255902704e-27, acceptances at previous T: 0.0, counter: 14378
# New temperature: 2.5050959127951352e-27, acceptances at previous T: 0.0, counter: 14453
# New temperature: 1.2525479563975676e-27, acceptances at previous T: 0.0, counter: 14528
# New temperature: 6.262739781987838e-28, acceptances at previous T: 0.0, counter: 14603
# New temperature: 3.131369890993919e-28, acceptances at previous T: 0.0, counter: 14678
# New temperature: 1.5656849454969595e-28, acceptances at previous T: 0.0, counter: 14753
# New temperature: 7.828424727484798e-29, acceptances at previous T: 0.0, counter: 14828
# New temperature: 3.914212363742399e-29, acceptances at previous T: 0.0, counter: 14903
# New temperature: 1.9571061818711994e-29, acceptances at previous T: 0.0, counter: 14978
# New temperature: 9.785530909355997e-30, acceptances at previous T: 0.0, counter: 15053

# %%
print(f"Best solution: {archive[0][0]}, Objective function value: {archive[0][1]}")
# Out:
# Best solution: [2.79710985 3.02417197 2.07300541 3.00135184 0.36039087 0.32466394
#  0.32660543 0.39753509], Objective function value: -0.6367427475434209
